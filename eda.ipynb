# %%
from PGNReader import PGNReader

# %%
file = PGNReader("poc-data.zip", "twic1579.pgn").get_game()

# %%
file.process_game()
# Out:
# r k q r b b n n
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R K Q R B B N N
# r k q r b b n n
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R K Q R B B N N
# r k q r b b n n
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . P . . .
# . . . . . . N .
# P P P P . P P P
# R K Q R B B N .
# r k q r b b n .
# p p p p . p p p
# . . . . . . n .
# . . . . p . . .
# . . . . P . . .
# . . . . . . N .
# P P P P . P P P
# R K Q R B B N .
# r k q r b b n .
# p p p p . p p p
# . . . . . . n .
# . . . . p . . .
# . . . P P . . .
# . . . . . . N .
# P P P . . P P P
# R K Q R B B N .
# r k q r b b n .
# p p p p . p p p
# . . . . . . n .
# . . . . . . . .
# . . . p P . . .
# . . . . . . N .
# P P P . . P P P
# R K Q R B B N .
# r k q r b b n .
# p p p p . p p p
# . . . . . . n .
# . . . . . . . .
# . . . p P . . .
# . . . . . N N .
# P P P . . P P P
# ...

# %%
file

# %%
file.__repr__()
# Out:
# '<PGNReader.PGNReader object at 0x7f969e472f10>'

# %%
file.game.headers
# Out:
# Headers(Event='Freestyle Weissenhaus RR', Site='Wangels GER', Date='2025.02.07', Round='1.1', White='Keymer,Vincent', Black='Sindarov,Javokhir', Result='0-1', WhiteTitle='GM', BlackTitle='GM', WhiteElo='2731', BlackElo='2700', WhiteFideId='12940690', BlackFideId='14205483', Variant='Chess960', SetUp='1', FEN='rkqrbbnn/pppppppp/8/8/8/8/PPPPPPPP/RKQRBBNN w KQkq - 0 1', EventDate='2025.02.07')

# %%
dir(file.game)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  'accept',
#  'accept_subgame',
#  'add_line',
#  'add_main_variation',
#  'add_variation',
#  'arrows',
#  'board',
#  'builder',
#  'clock',
#  'comment',
#  'demote',
#  'emt',
#  'end',
#  'errors',
#  'eval',
#  'eval_depth',
#  'from_board',
#  'game',
#  'has_variation',
#  'headers',
#  'is_end',
#  'is_main_variation',
#  'is_mainline',
#  'mainline',
#  'mainline_moves',
#  'move',
#  'nags',
#  'next',
#  'parent',
#  'ply',
#  'promote',
# ...
